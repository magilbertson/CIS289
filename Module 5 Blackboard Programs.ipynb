# %% [markdown]
# # Module 5: Data Analysis!

# %% [markdown]
# ## Topic 1: Data Analysis Start to Finish - Part 1

# %% [markdown]
# ### First import the library

# %%
import pandas as pd

# %% [markdown]
# ### Now we can bring in our dataset as a dataframe and assign it to a variable

# %%
kick_all = pd.read_csv('ks-projects-201801.csv',index_col='ID')

# %% [markdown]
# ### With that done, we can take a quick peek at the shape and some of the data in the dataframe

# %%
print(kick_all.shape)
kick_all.head()
# Out:
# (378661, 14)
#                                                          name        category  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah          Poetry
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 1000004038                                     Where is Hank?  Narrative Film
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 1000011046  Community Film Project: The Art of Neighborhoo...    Film & Video
#
#            main_category currency    deadline     goal             launched  \
# ID
# 1000002330    Publishing      GBP  2015-10-09   1000.0  2015-08-11 12:12:28
# 1000003930  Film & Video      USD  2017-11-01  30000.0  2017-09-02 04:43:57
# 1000004038  Film & Video      USD  2013-02-26  45000.0  2013-01-12 00:20:50
# 1000007540         Music      USD  2012-04-16   5000.0  2012-03-17 03:24:11
# 1000011046  Film & Video      USD  2015-08-29  19500.0  2015-07-04 08:35:03
#
#             pledged     state  backers country  usd pledged  usd_pledged_real  \
# ID
# 1000002330      0.0    failed        0      GB          0.0               0.0
# 1000003930   2421.0    failed       15      US        100.0            2421.0
# 1000004038    220.0    failed        3      US        220.0             220.0
# 1000007540      1.0    failed        1      US          1.0               1.0
# 1000011046   1283.0  canceled       14      US       1283.0            1283.0
#
#             usd_goal_real
# ID
# 1000002330        1533.95
# 1000003930       30000.00
# 1000004038       45000.00
# 1000007540        5000.00
# 1000011046       19500.00

# %% [markdown]
# ### Let's have a look at the shape of the backers because I'm interested in analyzing it

# %%
kick_all['backers'].value_counts(bins=10)
# Out:
# (-219.383, 21938.2]     378593
# (21938.2, 43876.4]          44
# (65814.6, 87752.8]          11
# (43876.4, 65814.6]           9
# (87752.8, 109691.0]          2
# (197443.8, 219382.0]         1
# (153567.4, 175505.6]         1
# (175505.6, 197443.8]         0
# (131629.2, 153567.4]         0
# (109691.0, 131629.2]         0
# Name: backers, dtype: int64

# %% [markdown]
# ### It appears to be heavily skewed in the low end with a long tail of larger counts

# %% [markdown]
# ### Let's break that data into equally sized buckets and see how that looks

# %%
pd.qcut(kick_all['backers'], q=6)
# Out:
# ID
# 1000002330    (-0.001, 1.0]
# 1000003930     (12.0, 34.0]
# 1000004038       (1.0, 3.0]
# 1000007540    (-0.001, 1.0]
# 1000011046     (12.0, 34.0]
#                   ...
# 999976400     (-0.001, 1.0]
# 999977640       (3.0, 12.0]
# 999986353     (-0.001, 1.0]
# 999987933       (3.0, 12.0]
# 999988282      (12.0, 34.0]
# Name: backers, Length: 378661, dtype: category
# Categories (6, interval[float64]): [(-0.001, 1.0] < (1.0, 3.0] < (3.0, 12.0] < (12.0, 34.0] < (34.0, 94.0] < (94.0, 219382.0]]

# %% [markdown]
# ### There are a lot of projects in here that are small and I don't want them.  I'm going to cut off any project that got less than 20 backers

# %% [markdown]
# ### I'm going to first create a list of the row IDs that need to be removed

# %%
kick_rows_to_delete = kick_all[kick_all["backers"]<20].index
print(kick_rows_to_delete.shape)
kick_rows_to_delete = list(kick_rows_to_delete)
print(kick_rows_to_delete[0:10])
# Out:
# (217405,)
# [1000002330, 1000003930, 1000004038, 1000007540, 1000011046, 1000023410, 100004721, 1000055792, 1000056157, 1000064368]

# %% [markdown]
# ### I can now use that list to drop the matching rows from the dataframe and assign the result to a new dataframe

# %%
kick_50_backers = kick_all.drop(kick_rows_to_delete)
print(kick_50_backers.head())
kick_50_backers.shape
# Out:
#                                                          name        category  \
# ID
# 1000014025                               Monarch Espresso Bar     Restaurants
# 1000030581  Chaser Strips. Our Strips make Shots their B*tch!          Drinks
# 1000034518  SPIN - Premium Retractable In-Ear Headphones w...  Product Design
# 100004195   STUDIO IN THE SKY - A Documentary Feature Film...     Documentary
# 100005484                                    Lisa Lim New CD!      Indie Rock
#
#            main_category currency    deadline      goal             launched  \
# ID
# 1000014025          Food      USD  2016-04-01   50000.0  2016-02-26 13:38:27
# 1000030581          Food      USD  2016-03-17   25000.0  2016-02-01 20:05:12
# 1000034518        Design      USD  2014-05-29  125000.0  2014-04-24 18:14:43
# 100004195   Film & Video      USD  2014-08-10   65000.0  2014-07-11 21:55:48
# 100005484          Music      USD  2013-04-08   12500.0  2013-03-09 06:42:58
#
#              pledged       state  backers country  usd pledged  \
# ID
# 1000014025  52375.00  successful      224      US     52375.00
# 1000030581    453.00      failed       40      US       453.00
# 1000034518   8233.00    canceled       58      US      8233.00
# 100004195    6240.57    canceled       43      US      6240.57
# 100005484   12700.00  successful      100      US     12700.00
#
#             usd_pledged_real  usd_goal_real
# ID
# 1000014025          52375.00        50000.0
# 1000030581            453.00        25000.0
# 1000034518           8233.00       125000.0
# 100004195            6240.57        65000.0
# 100005484           12700.00        12500.0
# (161256, 14)

# %% [markdown]
# ## Topic 2: Data Analysis Start to Finish - Part 2

# %% [markdown]
# ### I'm going to sort the new dataframe by backers to see the most backed projects

# %%
kick_50_backers.sort_values(by=["backers"], ascending=False, inplace=True)
kick_50_backers.head()
# Out:
#                                                          name        category  \
# ID
# 1955357092                                  Exploding Kittens  Tabletop Games
# 1386523707                      Fidget Cube: A Vinyl Desk Toy  Product Design
# 557230947   Bring Reading Rainbow Back for Every Child, Ev...             Web
# 1755266685                    The Veronica Mars Movie Project  Narrative Film
# 1929840910                              Double Fine Adventure     Video Games
#
#            main_category currency    deadline       goal             launched  \
# ID
# 1955357092         Games      USD  2015-02-20    10000.0  2015-01-20 19:00:19
# 1386523707        Design      USD  2016-10-20    15000.0  2016-08-30 22:02:09
# 557230947     Technology      USD  2014-07-02  1000000.0  2014-05-28 15:05:45
# 1755266685  Film & Video      USD  2013-04-13  2000000.0  2013-03-13 15:42:22
# 1929840910         Games      USD  2012-03-14   400000.0  2012-02-09 02:52:52
#
#                pledged       state  backers country  usd pledged  \
# ID
# 1955357092  8782571.99  successful   219382      US   8782571.99
# 1386523707  6465690.30  successful   154926      US     13770.00
# 557230947   5408916.95  successful   105857      US   5408916.95
# 1755266685  5702153.38  successful    91585      US   5702153.38
# 1929840910  3336371.92  successful    87142      US   3336371.92
#
#             usd_pledged_real  usd_goal_real
# ID
# 1955357092        8782571.99        10000.0
# 1386523707        6465690.30        15000.0
# 557230947         5408916.95      1000000.0
# 1755266685        5702153.38      2000000.0
# 1929840910        3336371.92       400000.0

# %% [markdown]
# ### I'm curious what categories of projects get the most backing so I'm going to groupby

# %%
kick_50_group_main_cat = kick_50_backers.groupby("main_category")
kick_50_group_main_cat = kick_50_group_main_cat.sum()

# %% [markdown]
# ### These are big numbers so they'll get output in scientific notation so I'm going to override that

# %%
kick_50_group_main_cat.head(15).style.format("{:.1f}") #suppresses scientific notation
# Out:
# <style  type="text/css" >
# </style><table id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >goal</th>        <th class="col_heading level0 col1" >pledged</th>        <th class="col_heading level0 col2" >backers</th>        <th class="col_heading level0 col3" >usd pledged</th>        <th class="col_heading level0 col4" >usd_pledged_real</th>        <th class="col_heading level0 col5" >usd_goal_real</th>    </tr>    <tr>        <th class="index_name level0" >main_category</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038level0_row0" class="row_heading level0 row0" >Art</th>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row0_col0" class="data row0 col0" >142146470.2</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row0_col1" class="data row0 col1" >95720660.4</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row0_col2" class="data row0 col2" >1105640.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row0_col3" class="data row0 col3" >66817995.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row0_col4" class="data row0 col4" >85404923.7</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row0_col5" class="data row0 col5" >142856680.3</td>
#             </tr>
#             <tr>
#                         <th id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038level0_row1" class="row_heading level0 row1" >Comics</th>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row1_col0" class="data row1 col0" >52849281.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row1_col1" class="data row1 col1" >73553239.7</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row1_col2" class="data row1 col2" >1433486.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row1_col3" class="data row1 col3" >56942471.8</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row1_col4" class="data row1 col4" >70473173.5</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row1_col5" class="data row1 col5" >49536295.1</td>
#             </tr>
#             <tr>
#                         <th id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038level0_row2" class="row_heading level0 row2" >Crafts</th>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row2_col0" class="data row2 col0" >26515268.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row2_col1" class="data row2 col1" >16291240.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row2_col2" class="data row2 col2" >214628.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row2_col3" class="data row2 col3" >9433316.9</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row2_col4" class="data row2 col4" >13132416.8</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row2_col5" class="data row2 col5" >23759516.5</td>
#             </tr>
#             <tr>
#                         <th id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038level0_row3" class="row_heading level0 row3" >Dance</th>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row3_col0" class="data row3 col0" >14070259.2</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row3_col1" class="data row3 col1" >13097024.9</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row3_col2" class="data row3 col2" >151584.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row3_col3" class="data row3 col3" >10534262.4</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row3_col4" class="data row3 col4" >12292145.6</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row3_col5" class="data row3 col5" >13013578.3</td>
#             </tr>
#             <tr>
#                         <th id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038level0_row4" class="row_heading level0 row4" >Design</th>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row4_col0" class="data row4 col0" >494352526.9</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row4_col1" class="data row4 col1" >805559046.9</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row4_col2" class="data row4 col2" >7177831.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row4_col3" class="data row4 col3" >506100782.5</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row4_col4" class="data row4 col4" >726617119.8</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row4_col5" class="data row4 col5" >435855051.4</td>
#             </tr>
#             <tr>
#                         <th id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038level0_row5" class="row_heading level0 row5" >Fashion</th>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row5_col0" class="data row5 col0" >118859029.2</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row5_col1" class="data row5 col1" >143705459.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row5_col2" class="data row5 col2" >1341225.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row5_col3" class="data row5 col3" >93816861.4</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row5_col4" class="data row5 col4" >125550275.7</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row5_col5" class="data row5 col5" >103389553.4</td>
#             </tr>
#             <tr>
#                         <th id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038level0_row6" class="row_heading level0 row6" >Film & Video</th>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row6_col0" class="data row6 col0" >771951714.7</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row6_col1" class="data row6 col1" >386772721.6</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row6_col2" class="data row6 col2" >4027937.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row6_col3" class="data row6 col3" >333189177.4</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row6_col4" class="data row6 col4" >374675340.1</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row6_col5" class="data row6 col5" >750292426.3</td>
#             </tr>
#             <tr>
#                         <th id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038level0_row7" class="row_heading level0 row7" >Food</th>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row7_col0" class="data row7 col0" >162878612.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row7_col1" class="data row7 col1" >126530496.1</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row7_col2" class="data row7 col2" >1269879.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row7_col3" class="data row7 col3" >99943098.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row7_col4" class="data row7 col4" >121344331.0</td>
#                         <td id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d69038row7_col5" class="data row7 col5" >156051248.4</td>
#             </tr>
#             <tr>
#                         <th id="T_0c275c5c_fc48_11ea_9a1f_a4c3f0d690

# %% [markdown]
# ### Now I want to see what the highest total goal category and figure out the average pledge per backer in each category

# %%
kick_50_group_main_cat.sort_values(by=["goal"], ascending=False, inplace=True)
kick_50_group_main_cat['pledge_per_backer'] = kick_50_group_main_cat["pledged"]/kick_50_group_main_cat['backers']
kick_50_group_main_cat.head(15).style.format("{:.1f}") #suppresses scientific notation
# Out:
# <style  type="text/css" >
# </style><table id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >goal</th>        <th class="col_heading level0 col1" >pledged</th>        <th class="col_heading level0 col2" >backers</th>        <th class="col_heading level0 col3" >usd pledged</th>        <th class="col_heading level0 col4" >usd_pledged_real</th>        <th class="col_heading level0 col5" >usd_goal_real</th>        <th class="col_heading level0 col6" >pledge_per_backer</th>    </tr>    <tr>        <th class="index_name level0" >main_category</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038level0_row0" class="row_heading level0 row0" >Film & Video</th>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row0_col0" class="data row0 col0" >771951714.7</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row0_col1" class="data row0 col1" >386772721.6</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row0_col2" class="data row0 col2" >4027937.0</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row0_col3" class="data row0 col3" >333189177.4</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row0_col4" class="data row0 col4" >374675340.1</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row0_col5" class="data row0 col5" >750292426.3</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row0_col6" class="data row0 col6" >96.0</td>
#             </tr>
#             <tr>
#                         <th id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038level0_row1" class="row_heading level0 row1" >Technology</th>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row1_col0" class="data row1 col0" >645186190.7</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row1_col1" class="data row1 col1" >721686069.4</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row1_col2" class="data row1 col2" >5271772.0</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row1_col3" class="data row1 col3" >496093947.3</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row1_col4" class="data row1 col4" >676696389.7</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row1_col5" class="data row1 col5" >596940092.2</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row1_col6" class="data row1 col6" >136.9</td>
#             </tr>
#             <tr>
#                         <th id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038level0_row2" class="row_heading level0 row2" >Games</th>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row2_col0" class="data row2 col0" >610839312.0</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row2_col1" class="data row2 col1" >765489923.5</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row2_col2" class="data row2 col2" >11254242.0</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row2_col3" class="data row2 col3" >570992825.4</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row2_col4" class="data row2 col4" >737073700.3</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row2_col5" class="data row2 col5" >568546244.9</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row2_col6" class="data row2 col6" >68.0</td>
#             </tr>
#             <tr>
#                         <th id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038level0_row3" class="row_heading level0 row3" >Design</th>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row3_col0" class="data row3 col0" >494352526.9</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row3_col1" class="data row3 col1" >805559046.9</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row3_col2" class="data row3 col2" >7177831.0</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row3_col3" class="data row3 col3" >506100782.5</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row3_col4" class="data row3 col4" >726617119.8</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row3_col5" class="data row3 col5" >435855051.4</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row3_col6" class="data row3 col6" >112.2</td>
#             </tr>
#             <tr>
#                         <th id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038level0_row4" class="row_heading level0 row4" >Publishing</th>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row4_col0" class="data row4 col0" >239919352.4</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row4_col1" class="data row4 col1" >138296315.2</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row4_col2" class="data row4 col2" >2129121.0</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row4_col3" class="data row4 col3" >98400524.4</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row4_col4" class="data row4 col4" >127355233.1</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row4_col5" class="data row4 col5" >227064893.8</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row4_col6" class="data row4 col6" >65.0</td>
#             </tr>
#             <tr>
#                         <th id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038level0_row5" class="row_heading level0 row5" >Music</th>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row5_col0" class="data row5 col0" >233561203.0</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row5_col1" class="data row5 col1" >192226348.8</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row5_col2" class="data row5 col2" >2591641.0</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row5_col3" class="data row5 col3" >159458528.5</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row5_col4" class="data row5 col4" >186034631.1</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row5_col5" class="data row5 col5" >222294614.3</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row5_col6" class="data row5 col6" >74.2</td>
#             </tr>
#             <tr>
#                         <th id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038level0_row6" class="row_heading level0 row6" >Food</th>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row6_col0" class="data row6 col0" >162878612.0</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row6_col1" class="data row6 col1" >126530496.1</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row6_col2" class="data row6 col2" >1269879.0</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row6_col3" class="data row6 col3" >99943098.0</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row6_col4" class="data row6 col4" >121344331.0</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row6_col5" class="data row6 col5" >156051248.4</td>
#                         <td id="T_0d49b8fa_fc48_11ea_8bb7_a4c3f0d69038row6_col6" class="data row6 col6" >99.6</td>
#             </tr>
#             <tr>

# %%
kick_50_group_main_cat.tail(15).style.format("{:.1f}") #suppresses scientific notation
# Out:
# <style  type="text/css" >
# </style><table id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >goal</th>        <th class="col_heading level0 col1" >pledged</th>        <th class="col_heading level0 col2" >backers</th>        <th class="col_heading level0 col3" >usd pledged</th>        <th class="col_heading level0 col4" >usd_pledged_real</th>        <th class="col_heading level0 col5" >usd_goal_real</th>        <th class="col_heading level0 col6" >pledge_per_backer</th>    </tr>    <tr>        <th class="index_name level0" >main_category</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038level0_row0" class="row_heading level0 row0" >Film & Video</th>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row0_col0" class="data row0 col0" >771951714.7</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row0_col1" class="data row0 col1" >386772721.6</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row0_col2" class="data row0 col2" >4027937.0</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row0_col3" class="data row0 col3" >333189177.4</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row0_col4" class="data row0 col4" >374675340.1</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row0_col5" class="data row0 col5" >750292426.3</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row0_col6" class="data row0 col6" >96.0</td>
#             </tr>
#             <tr>
#                         <th id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038level0_row1" class="row_heading level0 row1" >Technology</th>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row1_col0" class="data row1 col0" >645186190.7</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row1_col1" class="data row1 col1" >721686069.4</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row1_col2" class="data row1 col2" >5271772.0</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row1_col3" class="data row1 col3" >496093947.3</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row1_col4" class="data row1 col4" >676696389.7</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row1_col5" class="data row1 col5" >596940092.2</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row1_col6" class="data row1 col6" >136.9</td>
#             </tr>
#             <tr>
#                         <th id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038level0_row2" class="row_heading level0 row2" >Games</th>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row2_col0" class="data row2 col0" >610839312.0</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row2_col1" class="data row2 col1" >765489923.5</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row2_col2" class="data row2 col2" >11254242.0</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row2_col3" class="data row2 col3" >570992825.4</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row2_col4" class="data row2 col4" >737073700.3</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row2_col5" class="data row2 col5" >568546244.9</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row2_col6" class="data row2 col6" >68.0</td>
#             </tr>
#             <tr>
#                         <th id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038level0_row3" class="row_heading level0 row3" >Design</th>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row3_col0" class="data row3 col0" >494352526.9</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row3_col1" class="data row3 col1" >805559046.9</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row3_col2" class="data row3 col2" >7177831.0</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row3_col3" class="data row3 col3" >506100782.5</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row3_col4" class="data row3 col4" >726617119.8</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row3_col5" class="data row3 col5" >435855051.4</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row3_col6" class="data row3 col6" >112.2</td>
#             </tr>
#             <tr>
#                         <th id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038level0_row4" class="row_heading level0 row4" >Publishing</th>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row4_col0" class="data row4 col0" >239919352.4</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row4_col1" class="data row4 col1" >138296315.2</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row4_col2" class="data row4 col2" >2129121.0</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row4_col3" class="data row4 col3" >98400524.4</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row4_col4" class="data row4 col4" >127355233.1</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row4_col5" class="data row4 col5" >227064893.8</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row4_col6" class="data row4 col6" >65.0</td>
#             </tr>
#             <tr>
#                         <th id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038level0_row5" class="row_heading level0 row5" >Music</th>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row5_col0" class="data row5 col0" >233561203.0</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row5_col1" class="data row5 col1" >192226348.8</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row5_col2" class="data row5 col2" >2591641.0</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row5_col3" class="data row5 col3" >159458528.5</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row5_col4" class="data row5 col4" >186034631.1</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row5_col5" class="data row5 col5" >222294614.3</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row5_col6" class="data row5 col6" >74.2</td>
#             </tr>
#             <tr>
#                         <th id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038level0_row6" class="row_heading level0 row6" >Food</th>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row6_col0" class="data row6 col0" >162878612.0</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row6_col1" class="data row6 col1" >126530496.1</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row6_col2" class="data row6 col2" >1269879.0</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row6_col3" class="data row6 col3" >99943098.0</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row6_col4" class="data row6 col4" >121344331.0</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row6_col5" class="data row6 col5" >156051248.4</td>
#                         <td id="T_0f0c0268_fc48_11ea_92b4_a4c3f0d69038row6_col6" class="data row6 col6" >99.6</td>
#             </tr>
#             <tr>

# %% [markdown]
# ### Now to have a look at just the biggest categories

# %%
kick_50_group_main_cat_trimmed = kick_50_group_main_cat[kick_50_group_main_cat["goal"]>100000000]

# %%
kick_50_group_main_cat_trimmed.tail(15).style.format("{:.1f}") #suppresses scientific notation
# Out:
# <style  type="text/css" >
# </style><table id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >goal</th>        <th class="col_heading level0 col1" >pledged</th>        <th class="col_heading level0 col2" >backers</th>        <th class="col_heading level0 col3" >usd pledged</th>        <th class="col_heading level0 col4" >usd_pledged_real</th>        <th class="col_heading level0 col5" >usd_goal_real</th>        <th class="col_heading level0 col6" >pledge_per_backer</th>    </tr>    <tr>        <th class="index_name level0" >main_category</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038level0_row0" class="row_heading level0 row0" >Film & Video</th>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row0_col0" class="data row0 col0" >771951714.7</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row0_col1" class="data row0 col1" >386772721.6</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row0_col2" class="data row0 col2" >4027937.0</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row0_col3" class="data row0 col3" >333189177.4</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row0_col4" class="data row0 col4" >374675340.1</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row0_col5" class="data row0 col5" >750292426.3</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row0_col6" class="data row0 col6" >96.0</td>
#             </tr>
#             <tr>
#                         <th id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038level0_row1" class="row_heading level0 row1" >Technology</th>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row1_col0" class="data row1 col0" >645186190.7</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row1_col1" class="data row1 col1" >721686069.4</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row1_col2" class="data row1 col2" >5271772.0</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row1_col3" class="data row1 col3" >496093947.3</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row1_col4" class="data row1 col4" >676696389.7</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row1_col5" class="data row1 col5" >596940092.2</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row1_col6" class="data row1 col6" >136.9</td>
#             </tr>
#             <tr>
#                         <th id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038level0_row2" class="row_heading level0 row2" >Games</th>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row2_col0" class="data row2 col0" >610839312.0</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row2_col1" class="data row2 col1" >765489923.5</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row2_col2" class="data row2 col2" >11254242.0</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row2_col3" class="data row2 col3" >570992825.4</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row2_col4" class="data row2 col4" >737073700.3</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row2_col5" class="data row2 col5" >568546244.9</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row2_col6" class="data row2 col6" >68.0</td>
#             </tr>
#             <tr>
#                         <th id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038level0_row3" class="row_heading level0 row3" >Design</th>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row3_col0" class="data row3 col0" >494352526.9</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row3_col1" class="data row3 col1" >805559046.9</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row3_col2" class="data row3 col2" >7177831.0</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row3_col3" class="data row3 col3" >506100782.5</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row3_col4" class="data row3 col4" >726617119.8</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row3_col5" class="data row3 col5" >435855051.4</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row3_col6" class="data row3 col6" >112.2</td>
#             </tr>
#             <tr>
#                         <th id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038level0_row4" class="row_heading level0 row4" >Publishing</th>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row4_col0" class="data row4 col0" >239919352.4</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row4_col1" class="data row4 col1" >138296315.2</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row4_col2" class="data row4 col2" >2129121.0</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row4_col3" class="data row4 col3" >98400524.4</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row4_col4" class="data row4 col4" >127355233.1</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row4_col5" class="data row4 col5" >227064893.8</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row4_col6" class="data row4 col6" >65.0</td>
#             </tr>
#             <tr>
#                         <th id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038level0_row5" class="row_heading level0 row5" >Music</th>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row5_col0" class="data row5 col0" >233561203.0</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row5_col1" class="data row5 col1" >192226348.8</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row5_col2" class="data row5 col2" >2591641.0</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row5_col3" class="data row5 col3" >159458528.5</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row5_col4" class="data row5 col4" >186034631.1</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row5_col5" class="data row5 col5" >222294614.3</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row5_col6" class="data row5 col6" >74.2</td>
#             </tr>
#             <tr>
#                         <th id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038level0_row6" class="row_heading level0 row6" >Food</th>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row6_col0" class="data row6 col0" >162878612.0</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row6_col1" class="data row6 col1" >126530496.1</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row6_col2" class="data row6 col2" >1269879.0</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row6_col3" class="data row6 col3" >99943098.0</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row6_col4" class="data row6 col4" >121344331.0</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row6_col5" class="data row6 col5" >156051248.4</td>
#                         <td id="T_11d9280a_fc48_11ea_ad61_a4c3f0d69038row6_col6" class="data row6 col6" >99.6</td>
#             </tr>
#             <tr>

# %% [markdown]
# ## Topic 3: Data Analysis Start to Finish - Part 3

# %% [markdown]
# ### It's hard to do any decent analysis on the backer counts because they aren't discrete.  I'm going to create buckets of backer counts so I can see the data easier

# %%
kick_50_backers["backer_groups"] = pd.cut(kick_50_backers.backers,[0,50,100,200,500,1000,2000,5000,10000,100000000])

# %%
kick_50_backers.head(10)
# Out:
#                                                          name        category  \
# ID
# 1955357092                                  Exploding Kittens  Tabletop Games
# 1386523707                      Fidget Cube: A Vinyl Desk Toy  Product Design
# 557230947   Bring Reading Rainbow Back for Every Child, Ev...             Web
# 1755266685                    The Veronica Mars Movie Project  Narrative Film
# 1929840910                              Double Fine Adventure     Video Games
# 1118803016                      Bears vs Babies - A Card Game  Tabletop Games
# 1799979574   Pebble Time - Awesome Smartwatch, No Compromises  Product Design
# 286165030                          Torment: Tides of Numenera     Video Games
# 458565935                                    Project Eternity     Video Games
# 1194278206         Yooka-Laylee - A 3D Platformer Rare-vival!     Video Games
#
#            main_category currency    deadline       goal             launched  \
# ID
# 1955357092         Games      USD  2015-02-20    10000.0  2015-01-20 19:00:19
# 1386523707        Design      USD  2016-10-20    15000.0  2016-08-30 22:02:09
# 557230947     Technology      USD  2014-07-02  1000000.0  2014-05-28 15:05:45
# 1755266685  Film & Video      USD  2013-04-13  2000000.0  2013-03-13 15:42:22
# 1929840910         Games      USD  2012-03-14   400000.0  2012-02-09 02:52:52
# 1118803016         Games      USD  2016-11-18    10000.0  2016-10-18 18:59:32
# 1799979574        Design      USD  2015-03-28   500000.0  2015-02-24 15:44:42
# 286165030          Games      USD  2013-04-06   900000.0  2013-03-06 14:47:37
# 458565935          Games      USD  2012-10-17  1100000.0  2012-09-14 19:01:04
# 1194278206         Games      GBP  2015-06-17   175000.0  2015-05-01 17:57:02
#
#                 pledged       state  backers country  usd pledged  \
# ID
# 1955357092   8782571.99  successful   219382      US   8782571.99
# 1386523707   6465690.30  successful   154926      US     13770.00
# 557230947    5408916.95  successful   105857      US   5408916.95
# 1755266685   5702153.38  successful    91585      US   5702153.38
# 1929840910   3336371.92  successful    87142      US   3336371.92
# 1118803016   3215679.79  successful    85581      US   1231455.60
# 1799979574  20338986.27  successful    78471      US  20338986.27
# 286165030    4188927.49  successful    74405      US   4188927.49
# 458565935    3986929.49  successful    73986      US   3986929.49
# 1194278206   2090104.10  successful    73206      GB   3225225.40
#
#             usd_pledged_real  usd_goal_real       backer_groups
# ID
# 1955357092        8782571.99       10000.00  (10000, 100000000]
# 1386523707        6465690.30       15000.00  (10000, 100000000]
# 557230947         5408916.95     1000000.00  (10000, 100000000]
# 1755266685        5702153.38     2000000.00  (10000, 100000000]
# 1929840910        3336371.92      400000.00  (10000, 100000000]
# 1118803016        3215679.79       10000.00  (10000, 100000000]
# 1799979574       20338986.27      500000.00  (10000, 100000000]
# 286165030         4188927.49      900000.00  (10000, 100000000]
# 458565935         3986929.49     1100000.00  (10000, 100000000]
# 1194278206        3310374.26      277170.64  (10000, 100000000]

# %% [markdown]
# ### With my new buckets, I can do some counts

# %%
kick_50_backers['backer_groups'].value_counts()
# Out:
# (0, 50]               60097
# (50, 100]             41210
# (100, 200]            28309
# (200, 500]            18950
# (500, 1000]            6538
# (1000, 2000]           3542
# (2000, 5000]           1837
# (5000, 10000]           522
# (10000, 100000000]      251
# Name: backer_groups, dtype: int64

# %% [markdown]
# ### Let's see if more backers make for a higher chance of success.  First I'll create a from that is just the columns I'm interested in

# %%
kick_success_by_backers = kick_50_backers.loc[:,["backer_groups","state"]]
print(kick_success_by_backers)
# Out:
#                  backer_groups       state
# ID
# 1955357092  (10000, 100000000]  successful
# 1386523707  (10000, 100000000]  successful
# 557230947   (10000, 100000000]  successful
# 1755266685  (10000, 100000000]  successful
# 1929840910  (10000, 100000000]  successful
# ...                        ...         ...
# 227211348              (0, 50]  successful
# 1820873794             (0, 50]        live
# 1009757842             (0, 50]  successful
# 1452688704             (0, 50]      failed
# 1905906288             (0, 50]  successful
#
# [161256 rows x 2 columns]

# %% [markdown]
# ### With that data, I can now get counts by state by backer group

# %%
kick_success_by_backers.groupby('backer_groups')['state'].value_counts()
# Out:
# backer_groups       state
# (0, 50]             successful    34360
#                     failed        21105
#                     canceled       4130
#                     live            370
#                     suspended       132
# (50, 100]           successful    30576
#                     failed         8354
#                     canceled       1980
#                     live            188
#                     suspended       112
# (100, 200]          successful    23344
#                     failed         3604
#                     canceled       1168
#                     live            108
#                     suspended        85
# (200, 500]          successful    16565
#                     failed         1552
#                     canceled        684
#                     live             79
#                     suspended        70
# (500, 1000]         successful     6031
#                     failed          284
#                     canceled        158
#                     suspended        34
#                     live             31
# (1000, 2000]        successful     3396
#                     failed           61
#                     canceled         51
#                     live             24
#                     suspended        10
# (2000, 5000]        successful     1771
#                     failed           27
#                     canceled         20
#                     live             11
#                     suspended         8
# (5000, 10000]       successful      499
#                     suspended         8
#                     failed            7
#                     canceled          5
#                     live              3
# (10000, 100000000]  successful      249
#                     live              1
#                     suspended         1
# Name: state, dtype: int64

# %% [markdown]
# ### While counts are nice, it's easier to see if we look at percentages

# %%
kick_success_by_backers.groupby('backer_groups')['state'].value_counts(normalize=True) *100
# Out:
# backer_groups       state
# (0, 50]             successful    57.174235
#                     failed        35.118226
#                     canceled       6.872223
#                     live           0.615671
#                     suspended      0.219645
# (50, 100]           successful    74.195584
#                     failed        20.271779
#                     canceled       4.804659
#                     live           0.456200
#                     suspended      0.271779
# (100, 200]          successful    82.461408
#                     failed        12.730934
#                     canceled       4.125896
#                     live           0.381504
#                     suspended      0.300258
# (200, 500]          successful    87.414248
#                     failed         8.189974
#                     canceled       3.609499
#                     live           0.416887
#                     suspended      0.369393
# (500, 1000]         successful    92.245335
#                     failed         4.343836
#                     canceled       2.416641
#                     suspended      0.520037
#                     live           0.474151
# (1000, 2000]        successful    95.878035
#                     failed         1.722191
#                     canceled       1.439864
#                     live           0.677583
#                     suspended      0.282326
# (2000, 5000]        successful    96.407186
#                     failed         1.469788
#                     canceled       1.088732
#                     live           0.598802
#                     suspended      0.435493
# (5000, 10000]       successful    95.593870
#                     suspended      1.532567
#                     failed         1.340996
#                     canceled       0.957854
#                     live           0.574713
# (10000, 100000000]  successful    99.203187
#                     live           0.398406
#                     suspended      0.398406
# Name: state, dtype: float64

# %% [markdown]
# ### It also helps to look at the overall success rate in the data without the backer groups so we have something to compare against.

# %%
kick_success_by_backers['state'].value_counts(normalize=True) *100
# Out:
# successful    72.425832
# failed        21.700898
# canceled       5.082602
# live           0.505408
# suspended      0.285261
# Name: state, dtype: float64

# %% [markdown]
# ## Topic 4: Data Analysis Start to Finish - Part 4

# %% [markdown]
# ### No code to show here.  This is just the part of the analysis where you would want to think about what format/structure you need the data in for demonstration/visualization...which is the next module!
